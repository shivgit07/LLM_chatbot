# %% [markdown]
# # Web Scraping the contents of a website

# %% [markdown]
# ### contains only the text

# %% [markdown]
# ### 1. scraping from a wiki page

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the Wikipedia page you want to scrape
url = 'https://en.wikipedia.org/wiki/Cosmos'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the content you want to scrape (e.g., the main article text)
    content = soup.find('div', {'class': 'mw-parser-output'})

    # Initialize an empty string to store the scraped text
    scraped_text = ''

    # Extract the text from the content and store it
    for paragraph in content.find_all(['p', 'dl']):
        scraped_text += paragraph.get_text() + '\n'

    # Define the filename for the text file
    filename = 'wikipedia_scraped_data.txt'

    # Write the scraped text to a text file
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(scraped_text)

    print(f'Data has been scraped and saved to {filename}')
else:
    print(f'Failed to retrieve the Wikipedia page. Status code: {response.status_code}')
# Out:
# Data has been scraped and saved to wikipedia_scraped_data.txt

# %% [markdown]
# 2. scraping from iitb main website main page (text from a particular section only)

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the Wikipedia page you want to scrape
url = 'https://www.iitb.ac.in/'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the content you want to scrape (e.g., the main article text)
    content = soup.find('div', {'class': 'view-content'})

    # Initialize an empty string to store the scraped text
    scraped_text = ''

    # Extract the text from the content and store it
    for paragraph in content.find_all('p'):
        scraped_text += paragraph.get_text() + '\n'

    # Define the filename for the text file
    filename = 'scraped_data_1.txt'

    # Write the scraped text to a text file
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(scraped_text)

    print(f'Data has been scraped and saved to {filename}')
else:
    print(f'Failed to retrieve the Wikipedia page. Status code: {response.status_code}')
# Out:
# Data has been scraped and saved to scraped_data_1.txt

# %%
# Define the filename where you saved the scraped data
filename = 'scraped_data_1.txt'

# Read and print the text from the file
with open(filename, 'r', encoding='utf-8') as file:
    scraped_text = file.read()
    print(scraped_text)
# Out:
# On the occasion of Vigilance Awareness Week observed during October 30 - November 5, 2023, and National Unity Day (Rashtriya Ekta Diwas) 2023, the Institute employees ...more
# On the occasion of Vigilance Awareness Week observed during October 30 - November 5, 2023, and National Unity Day (Rashtriya Ekta Diwas) 2023, the Institute employees ...more
# IIT Bombay paid homage to the Father of the Nation Mahatma Gandhi and second Prime Minister of the nation Lal Bahadur Shastri during a function held at 9 am at P.C. Saxena ...more
# IIT Bombay paid homage to the Father of the Nation Mahatma Gandhi and second Prime Minister of the nation Lal Bahadur Shastri during a function held at 9 am at P.C. Saxena ...more
# A senior delegation consisting of 21 members from Saint Petersburg, Russia led by Prof. Vladimir Kniagninin  - Vice-governor of Saint Petersburg visited IIT Bombay ...more
# A senior delegation consisting of 21 members from Saint Petersburg, Russia led by Prof. Vladimir Kniagninin  - Vice-governor of Saint Petersburg visited IIT Bombay ...more
# Prof Debabrata Maiti, Department of Chemistry, has been awarded the Shanti Swarup Bhatnagar Prize for Science and Technology 2022 award for his significant contributions to ...more
# Prof Debabrata Maiti, Department of Chemistry, has been awarded the Shanti Swarup Bhatnagar Prize for Science and Technology 2022 award for his significant contributions to ...more

# %% [markdown]
# 3. Text that is hyperlinked along with normal text.

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the Wikipedia page you want to scrape
url = 'https://www.iitb.ac.in/'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the content you want to scrape (e.g., the main article text)
    content = soup.find('div', {'class': 'view-content'})

    # Initialize an empty string to store the scraped text
    scraped_text = ''

    # Extract the text from the content and store it
    for paragraph in content.find_all(['p','a']):
        scraped_text += paragraph.get_text() + '\n'

    # Define the filename for the text file
    filename = 'scraped_data_hplnk.txt'

    # Write the scraped text to a text file
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(scraped_text)

    print(f'Data has been scraped and saved to {filename}')
else:
    print(f'Failed to retrieve the Wikipedia page. Status code: {response.status_code}')
# Out:
# Data has been scraped and saved to scraped_data_hplnk.txt

# %%
# Define the filename where you saved the scraped data
filename = 'scraped_data_hplnk.txt'

# Read and print the text from the file
with open(filename, 'r', encoding='utf-8') as file:
    scraped_text = file.read()
    print(scraped_text)
# Out:
# IIT Bombay Observes Vigilance Awareness Week and...
# On the occasion of Vigilance Awareness Week observed during October 30 - November 5, 2023, and National Unity Day (Rashtriya Ekta Diwas) 2023, the Institute employees ...more
# On the occasion of Vigilance Awareness Week observed during October 30 - November 5, 2023, and National Unity Day (Rashtriya Ekta Diwas) 2023, the Institute employees ...more
# ...more
#
# IIT Bombay Celebrates Birth Anniversaries of...
# IIT Bombay paid homage to the Father of the Nation Mahatma Gandhi and second Prime Minister of the nation Lal Bahadur Shastri during a function held at 9 am at P.C. Saxena ...more
# IIT Bombay paid homage to the Father of the Nation Mahatma Gandhi and second Prime Minister of the nation Lal Bahadur Shastri during a function held at 9 am at P.C. Saxena ...more
# ...more
#
# Saint Petersburg, Russia Delegation Visits IIT...
# A senior delegation consisting of 21 members from Saint Petersburg, Russia led by Prof. Vladimir Kniagninin  - Vice-governor of Saint Petersburg visited IIT Bombay ...more
# A senior delegation consisting of 21 members from Saint Petersburg, Russia led by Prof. Vladimir Kniagninin  - Vice-governor of Saint Petersburg visited IIT Bombay ...more
# ...more
#
# Prof. Debabrata Maiti Wins Shanti Swarup...
# Prof Debabrata Maiti, Department of Chemistry, has been awarded the Shanti Swarup Bhatnagar Prize for Science and Technology 2022 award for his significant contributions to ...more
# Prof Debabrata Maiti, Department of Chemistry, has been awarded the Shanti Swarup Bhatnagar Prize for Science and Technology 2022 award for his significant contributions to ...more
# ...more

# %% [markdown]
# # All text with their hyperlinks

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Define the URL of the Wikipedia page you want to scrape
url = 'https://www.iitb.ac.in/'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all <a> and <p> tags in the entire document
    links_and_paragraphs = soup.find_all(['a', 'p'])

    # Initialize an empty list to store the extracted data
    extracted_data = []

    base_url = 'https://www.iitb.ac.in'  # Change this to match the base URL of your page

    # Extract the text and hyperlinks from the <a> tags and text from <p> tags
    for item in links_and_paragraphs:
        if item.name == 'a':  # <a> tag for hyperlinks
            hyperlink = item.get('href')  # Get the hyperlink
            text = item.get_text()  # Get the text associated with the hyperlink
            if hyperlink:
                # Check if the hyperlink is an absolute URL or a relative URL
                complete_link = hyperlink if hyperlink.startswith(('http:', 'https:')) else urljoin(base_url, hyperlink)
                extracted_data.append(f'Text: {text}\nLink: {complete_link}')
        elif item.name == 'p':  # <p> tag for paragraphs
            text = item.get_text()  # Get the text from the paragraph
            extracted_data.append(f'Paragraph: {text}')

    # Define the filename for the text file
    filename = 'scraped_data_hplnk_2.txt'

    # Write the extracted data to a text file
    with open(filename, 'w', encoding='utf-8') as file:
        for item in extracted_data:
            file.write(item + '\n')

    print(f'Hyperlinks and paragraphs from the entire page have been scraped and saved to {filename}')
else:
    print(f'Failed to retrieve the Wikipedia page. Status code: {response.status_code}')
# Out:
# Hyperlinks and paragraphs from the entire page have been scraped and saved to scraped_data_hplnk_2.txt

# %%
# Define the filename where you saved the scraped data
filename = 'scraped_data_hplnk_2.txt'

# Read and print the text from the file
with open(filename, 'r', encoding='utf-8') as file:
    scraped_text = file.read()
    print(scraped_text)
# Out:
# Text: Skip to main content
# Link: https://www.iitb.ac.in#main-content
# Text: English
# Link: https://www.iitb.ac.in/en
# Text: हिन्दी
# Link: https://www.iitb.ac.in/hi
# Text:
# Link: https://twitter.com/iitbombay
# Text:
# Link: https://www.facebook.com/iitbombay
# Text:
# Link: https://plus.google.com/+iitbombay
# Text:
# Link: https://www.linkedin.com/edu/school?id=13496&trk=edu-cp-title
# Text:
# Link: https://www.iitb.ac.in
# Text: भारतीय प्रौद्योगिकी संस्थान मुंबई
# Link: https://www.iitb.ac.in
# Text: Indian Institute of Technology Bombay
# Link: https://www.iitb.ac.in
# Text:
#
#
# Link: https://www.iitb.ac.in/en/azadi-ka-amrit-mahotsav
# Text: Home
# Link: https://www.iitb.ac.in/en
# Text: About IITB
# Link: https://www.iitb.ac.in/en/about-iit-bombay
# Text: Contact us
# Link: https://www.iitb.ac.in/en/about-iit-bombay/contact-us
# Text: Students
# Link: https://www.iitb.ac.in/en/information-students
# Text: Academic Divisions
# Link: https://www.iitb.ac.in/en/education/academic-divisions
# Text: Current Students
# Link: https://www.iitb.ac.in/en/students/information-current-students
# Text: Academic Time table
# Link: http://www.iitb.ac.in/newacadhome/timetable.jsp
# Text: Academic Calendar
# Link: http://www.iitb.ac.in/newacadhome/toacadcalender.jsp
# Text: Academic Rulebook
# Link: http://www.iitb.ac.in/newacadhome/rules.jsp
# Text: Student Affairs Office
# Link: https://www.iitb.ac.in/en/about-iit-bombay/student-affairs-office
# Text: Gymkhana
# Text:
# Link: https://www.iitb.ac.in/sites/www.iitb.ac.in/files/reshigh/2023-09/image.jpg
# Text: A Breakthrough in Solar Cell Technology from IIT Bombay; Measures one of the Highest Efficiency for a Perovskite-based Solar Device
# Link: https://www.iitb.ac.in/en/research-highlight/breakthrough-solar-cell-technology-iit-bombay-measures-one-highest-efficiency
# Paragraph: First experimental demonstration of a 4T- silicon-p...
# Text: A Breakthrough in Solar Cell Technology from IIT Bombay; Measures one of the Highest Efficiency for a Perovskite-based Solar Device
# Link: https://www.iitb.ac.in/en/research-highlight/breakthrough-solar-cell-technology-iit-bombay-measures-one-highest-efficiency
# Paragraph: First experimental demonstration of a 4T- silicon-perovskite tandem solar cell from India, with efficiency greater than 26%.
# Paragraph: A team at the National Centre for...
# Text:
# Link: https://www.iitb.ac.in/en/research-highlight/breakthrough-solar-cell-technology-iit-bombay-measures-one-highest-efficiency
# Text:
# Link: https://www.iitb.ac.in/sites/www.iitb.ac.in/files/reshigh/2023-06/img_0.jpg
# Text: Scientists at IIT Bombay develop new technique that offers insights into interfacial reactions
# Link: https://www.iitb.ac.in/en/research-highlight/scientists-iit-bombay-develop-new-technique-offers-insights-interfacial-reactions
# Paragraph: Researchers have come up with an innovative approach for measuring...
# Text: Scientists at IIT Bombay develop new technique that offers insights into interfacial reactions
# Link: https://www.iitb.ac.in/en/research-highlight/scientists-iit-bombay-develop-new-technique-offers-insights-interfacial-reactions
# Paragraph: Researchers have come up with an innovative approach for measuring the coating performance.
# Paragraph: How often have we not encountered corrosion in some of our devices? Although there...
# Text:
# Link: https://www.iitb.ac.in/en/research-highlight/scientists-iit-bombay-develop-new-technique-offers-insights-interfacial-reactions
# Text:
# Link: https://www.iitb.ac.in/sites/www.iitb.ac.in/files/reshigh/2023-06/img.jpg
# Text: Read Archived Highlights
# Link: https://www.iitb.ac.in/en/research-highlights/archive
# Text:
# Link: javascript:$('#searchform').submit();
# Text: Academic Divisions
# Link: https://www.iitb.ac.in/en/education/academic-divisions
# Text: Academics Website
# Link: http://www.iitb.ac.in/acad/
# Text: Academic Time table
# Link: http://www.iitb.ac.in/newacadhome/timetable.jsp
# Text: Academic Calendar
# Link: http://www.iitb.ac.in/newacadhome/toacadcalender.jsp
# Text: Entrance exams
# Link: https://www.iitb.ac.in/en/entrance-exams
# Text: CEP/ QIP/ CDEEP
# Link: https://www.iitb.ac.in/en/cep-qip-cdeep
# Text: Central Library
# Link: http://www.library.iitb.ac.in/
# Text: R&D Jobs
# Link: https://ep.iitb.ac.in/jobsearch
# Text: Internships
# Link: http://www.ircc.iitb.ac.in/fellowship/
# Text: Areas of Expertise
# Link: http://www.ircc.iitb.ac.in/IRCC-Webpage/rnd/WebExpertiesSearch.jsp
# Text: Technologies for Licensing
# Link: http://www.ircc.iitb.ac.in/IRCC-Webpage/rnd/Licensing.jsp
# Text: Research Publications
# Link: https://www.ircc.iitb.ac.in/IRCC-Webpage/DisplayResearchPapersDataCP.jsp
# Text: COVID - related Research & Development Works by CFTIs
# Link: https://www.iitb.ac.in/sites/www.iitb.ac.in/files/basicpagefile/Covid%20E%20Book.pdf
# Text: IIT Bombay's Ideas and Innovations for Society (IBIS)
# Link: https://rnd.iitb.ac.in/sites/rnd.iitb.ac.in/files/brochures/2022-06/IBIS%20IIT%20Bombays%20Ideas%20and%20Innovations%20for%20Society%20June%202022.pdf
